# %%
# import
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import h3


def lat_lng_to_h3(lat, lng, resolution):
    # Convert latitude and longitude to H3 index
    h3_index = h3.geo_to_h3(lat, lng, resolution)
    return h3_index

# %%
# load data 
df = pd.read_csv('./bristol_density.csv')

# %%
# load data 
df1 = pd.read_csv('./Bristol charging points.csv')

# %%
resolution = 7
hex_col = 'hex'+str(resolution)

# find hexs containing the points
df[hex_col] = df.apply(lambda x: h3.geo_to_h3(x.Latitude,x.Longitude,resolution),1)
df1[hex_col] = df1.apply(lambda x: h3.geo_to_h3(x.Latitude,x.Longitude,resolution),1)

# %%
df1.columns
# Out:
# Index(['chargeDeviceID', 'reference', 'name', 'Latitude', 'Longitude',
#        'subBuildingName', 'buildingName', 'buildingNumber', 'thoroughfare',
#        'street',
#        ...
#        'connector8OutputCurrent', 'connector8RatedVoltage',
#        'connector8ChargeMethod', 'connector8ChargeMode',
#        'connector8TetheredCable', 'connector8Status', 'connector8Description',
#        'connector8Validated', 'total_connectors', 'hex7'],
#       dtype='object', length=160)

# %%
df.head()
# Out:
#    Count_point_id Direction_of_travel  Year           Count_date  hour  \
# 0           18042                   N  2014  2014-09-30 00:00:00     7
# 1           18042                   N  2014  2014-09-30 00:00:00     8
# 2           18042                   N  2014  2014-09-30 00:00:00     9
# 3           18042                   N  2014  2014-09-30 00:00:00    10
# 4           18042                   N  2014  2014-09-30 00:00:00    11
#
#    Region_id Region_name Region_ons_code  Local_authority_id  \
# 0          1  South West       E12000009                 144
# 1          1  South West       E12000009                 144
# 2          1  South West       E12000009                 144
# 3          1  South West       E12000009                 144
# 4          1  South West       E12000009                 144
#
#   Local_authority_name  ... LGVs HGVs_2_rigid_axle HGVs_3_rigid_axle  \
# 0     Bristol, City of  ...  345              39.0              15.0
# 1     Bristol, City of  ...  397              31.0               6.0
# 2     Bristol, City of  ...  328              38.0               9.0
# 3     Bristol, City of  ...  267              35.0               8.0
# 4     Bristol, City of  ...  267              32.0               9.0
#
#   HGVs_4_or_more_rigid_axle HGVs_3_or_4_articulated_axle  \
# 0                       7.0                          1.0
# 1                       5.0                          3.0
# 2                      10.0                          0.0
# 3                       9.0                          7.0
# 4                      14.0                          0.0
#
#   HGVs_5_articulated_axle  HGVs_6_articulated_axle  All_HGVs  \
# 0                       5                      6.0      73.0
# 1                      10                      7.0      62.0
# 2                      12                     11.0      80.0
# 3                      12                      4.0      75.0
# 4                      21                      7.0      83.0
#
#    All_motor_vehicles             hex7
# 0              1578.0  871958390ffffff
# 1              1777.0  871958390ffffff
# 2              1379.0  871958390ffffff
# 3              1180.0  871958390ffffff
# 4              1224.0  871958390ffffff
#
# [5 rows x 36 columns]

# %%
df1.head()
# Out:
#                      chargeDeviceID reference                           name  \
# 0  ac7a21c48f5833b33a5b606b2089e6a9     CM167     NCP Prince Street Car Park
# 1  a999c0cab150490ffefb7ce9ec889830  CYC60469  Longwell Green Leisure Centre
# 2  6928deac51a9dcc1f063ccec46d3c067  CYC60466   Bradley Stoke Leisure Centre
# 3  a76a25b08df9964728e96bc8c8720e5d     60467             Memorial Woodlands
# 4  beab105a740056efe867b95bcb90b82d   CM22571    Cribbs Causeway Retail Park
#
#     Latitude  Longitude        subBuildingName                   buildingName  \
# 0  51.450340  -2.596704                    NaN                            NaN
# 1  51.449065  -2.500966  Aspects Leisure Park   Longwell Green Leisure Centre
# 2  51.535657  -2.545928                    NaN   Bradley Stoke Leisure Centre
# 3  51.571359  -2.498436                    NaN             Memorial Woodlands
# 4  51.526138  -2.600600                    NaN                            NaN
#
#        buildingNumber    thoroughfare            street  ...  \
# 0                 NaN             NaN     Prince Street  ...
# 1                 NaN             NaN      Leisure Road  ...
# 2                 NaN             NaN  Fiddlers Wood Ln  ...
# 3  Memorial Woodlands  Earthcott Road               NaN  ...
# 4                 NaN   Lysander Road          Patchway  ...
#
#   connector8OutputCurrent connector8RatedVoltage connector8ChargeMethod  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#   connector8ChargeMode connector8TetheredCable connector8Status  \
# 0                  NaN                     NaN              NaN
# 1                  NaN                     NaN              NaN
# 2                  NaN                     NaN              NaN
# 3                  NaN                     NaN              NaN
# 4                  NaN                     NaN              NaN
#
#    connector8Description connector8Validated total_connectors             hex7
# 0                    NaN                 NaN                2  87195876cffffff
# 1                    NaN                 NaN                3  871958382ffffff
# 2                    NaN                 NaN                3  8719580ebffffff
# 3                    NaN                 NaN                3  8719580edffffff
# 4                    NaN                 NaN                2  8719580c8ffffff
#
# [5 rows x 160 columns]

# %%
df['mean_car']=df.groupby(hex_col)['All_motor_vehicles'].transform('mean')
df1['total_charger']=df1.groupby(hex_col)['total_connectors'].transform('sum')

# %%
df[hex_col].value_counts()
# Out:
# hex7
# 871958390ffffff    2868
# 87195876cffffff    2748
# 871958766ffffff    2388
# 871958392ffffff    2364
# 871958393ffffff    2304
#                    ...
# 871958744ffffff      24
# 871958382ffffff      24
# 871958752ffffff      24
# 87195862cffffff      24
# 87195874dffffff      24
# Name: count, Length: 83, dtype: int64

# %%
k = 2
for s_indexed in df1[hex_col].loc[0:10]:
    # Use the hex string directly without converting it to an integer
    neighboring = h3.k_ring(s_indexed, k)
    print('for ' +s_indexed )
    print("Neighbors:")
    for neighbor in neighboring:
        print(neighbor)
# Out:
# for 87195876cffffff
# Neighbors:
# 871958768ffffff
# 87195876effffff
# 871958745ffffff
# 871958760ffffff
# 871958396ffffff
# 871958769ffffff
# 87195839affffff
# 871958393ffffff
# 87195876affffff
# 87195876bffffff
# 871958765ffffff
# 871958391ffffff
# 871958392ffffff
# 87195876cffffff
# 87195876dffffff
# 871958390ffffff
# 871958761ffffff
# 87195839effffff
# 871958763ffffff
# for 871958382ffffff
# Neighbors:
# 871958384ffffff
# 8719583b1ffffff
# 871958383ffffff
# 871958395ffffff
# 8719583b3ffffff
# 87195839cffffff
# 87195838effffff
# 871958385ffffff
# 871958398ffffff
# 871958386ffffff
# 871958394ffffff
# 871958393ffffff
# 871958380ffffff
# 871958391ffffff
# 87195839dffffff
# 871958390ffffff
# 871958381ffffff
# 871958382ffffff
# 87195839effffff
# for 8719580ebffffff
# Neighbors:
# 8719580edffffff
# 8719580e9ffffff
# 8719580cdffffff
# 8719583b4ffffff
# 8719580c5ffffff
# 8719580c1ffffff
# 8719583b2ffffff
# 8719580c9ffffff
# 8719580eaffffff
# 8719583b6ffffff
# 8719583b0ffffff
# 87195805affffff
# 8719580eeffffff
# 8719580ceffffff
# 8719580ecffffff
# 8719580ebffffff
# 8719580ccffffff
# 8719580c8ffffff
# 8719580e8ffffff
# for 8719580edffffff
# Neighbors:
# 8719580edffffff
# 8719580e9ffffff
# 871958052ffffff
# 8719583b4ffffff
# 871958053ffffff
# 871958051ffffff
# 8719580eaffffff
# 87195805bffffff
# 8719583b6ffffff
# 87195805affffff
# 8719580eeffffff
# 871958050ffffff
# 8719580e1ffffff
# 8719580ecffffff
# 8719580ebffffff
# 871958058ffffff
# 87195805cffffff
# 8719580e8ffffff
# 87195805effffff
# for 8719580c8ffffff
# Neighbors:
# 8719580cdffffff
# 871958396ffffff
# 8719580ddffffff
# 8719580c1ffffff
# 8719583b2ffffff
# 8719580c9ffffff
# 8719580eaffffff
# 8719580c3ffffff
# 8719583b6ffffff
# 8719580d9ffffff
# 871958394ffffff
# 8719580ceffffff
# 871958765ffffff
# 871958764ffffff
# 8719580ebffffff
# 8719580ccffffff
# 8719580c8ffffff
# 8719580cbffffff
# 8719580caffffff
# for 871958382ffffff
# Neighbors:
# 871958384ffffff
# 8719583b1ffffff
# 871958383ffffff
# 871958395ffffff
# 8719583b3ffffff
# 87195839cffffff
# 87195838effffff
# 871958385ffffff
# 871958398ffffff
# 871958386ffffff
# 871958394ffffff
# 871958393ffffff
# 871958380ffffff
# 871958391ffffff
# 87195839dffffff
# 871958390ffffff
# 871958381ffffff
# 871958382ffffff
# 87195839effffff
# for 871958775ffffff
# Neighbors:
# 8719580daffffff
# 8719580dbffffff
# 871958776ffffff
# 871958766ffffff
# 871958775ffffff
# 871958771ffffff
# 871958774ffffff
# 871958760ffffff
# 871958746ffffff
# 871958762ffffff
# 8719580d9ffffff
# 871958770ffffff
# 8719580d8ffffff
# 871958729ffffff
# 871958764ffffff
# 871958744ffffff
# 871958773ffffff
# 871958772ffffff
# 871958763ffffff
# for 871958763ffffff
# Neighbors:
# 871958768ffffff
# 87195876effffff
# 871958745ffffff
# 871958766ffffff
# 871958771ffffff
# 871958760ffffff
# 871958746ffffff
# 871958762ffffff
# 87195876affffff
# 871958763ffffff
# 871958765ffffff
# 871958740ffffff
# 871958764ffffff
# 871958744ffffff
# 871958392ffffff
# 87195876cffffff
# 871958761ffffff
# 871958741ffffff
# 871958775ffffff
# for 87195876cffffff
# Neighbors:
# 871958768ffffff
# 87195876effffff
# 871958745ffffff
# 871958760ffffff
# 871958396ffffff
# 871958769ffffff
# 87195839affffff
# 871958393ffffff
# 87195876affffff
# 87195876bffffff
# 871958765ffffff
# 871958391ffffff
# 871958392ffffff
# 87195876cffffff
# 87195876dffffff
# 871958390ffffff
# 871958761ffffff
# 87195839effffff
# 871958763ffffff
# for 871958393ffffff
# Neighbors:
# 871958768ffffff
# 87195876effffff
# 871958395ffffff
# 871958396ffffff
# 871958769ffffff
# 87195839cffffff
# 87195839affffff
# 871958398ffffff
# 871958394ffffff
# 871958393ffffff
# 871958765ffffff
# 871958391ffffff
# 871958392ffffff
# 87195876cffffff
# 87195876dffffff
# 871958390ffffff
# 871958761ffffff
# 871958382ffffff
# 87195839effffff
# for 87195876cffffff
# Neighbors:
# 871958768ffffff
# 87195876effffff
# 871958745ffffff
# 871958760ffffff
# 871958396ffffff
# 871958769ffffff
# 87195839affffff
# 871958393ffffff
# 87195876affffff
# 87195876bffffff
# 871958765ffffff
# 871958391ffffff
# 871958392ffffff
# 87195876cffffff
# 87195876dffffff
# 871958390ffffff
# 871958761ffffff
# 87195839effffff
# 871958763ffffff

# %%
df2=df[[hex_col,'mean_car']]
df2=df2.drop_duplicates(subset=[hex_col, 'mean_car'])

# %%
df3=df1[[hex_col,'total_charger']]
df3=df3.drop_duplicates(subset=[hex_col, 'total_charger'])

# %%
df2=pd.merge(df2,df3[[hex_col,'total_charger']],on=hex_col,how='left')

# %%
df2.fillna(0, inplace=True)
#df2.to_csv('./Result.csv')

# %%
# calculate distance between two H3 cells
def calculate_grid_distance(start_index, end_index):
    # Calculate the grid distance between two H3 cells
    distance = h3.h3_distance(start_index, end_index)
    return distance

# %%
listofcharger1=df2[df2.total_charger>0][[hex_col,'total_charger']]

# %%
listofcharger1.head()
# Out:
#               hex7  total_charger
# 0  871958390ffffff           20.0
# 2  871958394ffffff            6.0
# 3  87195876cffffff           62.0
# 4  871958771ffffff            6.0
# 6  871958766ffffff            2.0

# %%
def getchargercount1(start_index,k=1):
    total=0
    charger_count=0
    neighboring = h3.k_ring(start_index, k)
    for n in neighboring:
        if n in listofcharger1[hex_col].to_list():
            total=total+1
            charger_count=charger_count+listofcharger1[listofcharger1[hex_col]==n]['total_charger'].values[0]
    return pd.Series([total, charger_count], index=['total_number_of_cell','charger_count'])

# %%
result=getchargercount1('871958390ffffff',0)
print(result)
# Out:
# total_number_of_cell     1.0
# charger_count           20.0
# dtype: float64

# %%
#it is a simple script to get the list of hexagons with chargers
listofcharger=df2[df2.total_charger>0][hex_col].to_list()

# %%
#it finds closest charging neighborhood
def calculate_min_grid_distance(start_index,listofcharger):
    low_distance=100
    for i in range(0,len(listofcharger)) :
        grid_distance = calculate_grid_distance(start_index, listofcharger[i])
        
        if grid_distance < low_distance:
            low_distance = grid_distance
            closest_charger = listofcharger[i]
    return pd.Series([low_distance, closest_charger], index=['min_k', 'min_k_hex'])

# %%
#testing distance
result1=calculate_min_grid_distance('8719586e4ffffff',listofcharger)
print(result1[0])
# Out:
# 0

# %%
def getchargercount(start_index,k=1):
    total=0
    neighboring = h3.k_ring(start_index, k)
    for n in neighboring:
        if n in listofcharger:
            total=total+1
    return total

# %%
df2[['min_k','min_k_hex']] = df2[hex_col].apply(lambda x: calculate_min_grid_distance(x, listofcharger))

# %%
df2['total_number_of_cell']=df2[[hex_col,'min_k']].apply(lambda x: getchargercount(x[hex_col],x['min_k']),axis=1)

# %%
df2[['total_number_of_cell','charger_count']]=df2[[hex_col,'min_k']].apply(lambda x: getchargercount1(x[hex_col],x['min_k']),axis=1)

# %%
df2.head(100)
# Out:
#                hex7     mean_car  total_charger  min_k        min_k_hex  \
# 0   871958390ffffff   877.440725           20.0      0  871958390ffffff
# 1   871958768ffffff   877.775974            0.0      1  87195876cffffff
# 2   871958394ffffff   951.128205            6.0      0  871958394ffffff
# 3   87195876cffffff   841.788210           62.0      0  87195876cffffff
# 4   871958771ffffff  1998.339689            6.0      0  871958771ffffff
# ..              ...          ...            ...    ...              ...
# 78  8719580caffffff   188.562500           13.0      0  8719580caffffff
# 79  8719580c8ffffff     6.958333           26.0      0  8719580c8ffffff
# 80  8719586e1ffffff    10.208333            0.0      2  8719586e4ffffff
# 81  871958662ffffff    61.750000            0.0      1  871958666ffffff
# 82  87195874dffffff    13.750000            0.0      2  871958769ffffff
#
#     total_number_of_cell  charger_count
# 0                    1.0           20.0
# 1                    4.0           88.0
# 2                    1.0            6.0
# 3                    1.0           62.0
# 4                    1.0            6.0
# ..                   ...            ...
# 78                   1.0           13.0
# 79                   1.0           26.0
# 80                   3.0           26.0
# 81                   1.0            5.0
# 82                   2.0           10.0
#
# [83 rows x 7 columns]

# %%
import math

# Define the H3 resolution (level of detail)
resolution = 7

# Get the length of one edge of the hexagon in meters
edge_length_meters = h3.edge_length(resolution, unit='m')

# Calculate the area of one hexagon
area_hexagon = (3 * math.sqrt(3) / 2) * (edge_length_meters ** 2)

print("Area of one hexagon at resolution", resolution, ":", area_hexagon, "square meters")

df2['cars_density'] = df2['mean_car']*1000000 / area_hexagon

df2.head()
# Out:
# Area of one hexagon at resolution 7 : 3870969.8983452995 square meters
#               hex7     mean_car  total_charger  min_k        min_k_hex  \
# 0  871958390ffffff   877.440725           20.0      0  871958390ffffff
# 1  871958768ffffff   877.775974            0.0      1  87195876cffffff
# 2  871958394ffffff   951.128205            6.0      0  871958394ffffff
# 3  87195876cffffff   841.788210           62.0      0  87195876cffffff
# 4  871958771ffffff  1998.339689            6.0      0  871958771ffffff
#
#    total_number_of_cell  charger_count  cars_density
# 0                   1.0           20.0    226.672061
# 1                   4.0           88.0    226.758667
# 2                   1.0            6.0    245.707983
# 3                   1.0           62.0    217.461833
# 4                   1.0            6.0    516.237465

# %%
records = [{row['hex7']: row['charger_count']} for index, row in df2[['hex7', 'charger_count']].iterrows()]

# %%
import json


file_path = 'bristol_density.json'

# Write records to JSON file
with open(file_path, 'w') as json_file:
    json.dump(records, json_file, indent=4)

print(f"Records have been written to {file_path}")
# Out:
# Records have been written to bristol_density.json

# %%
import folium


# Initialize Folium map
m = folium.Map(location=[51.45498615600733, -2.594947745448589], zoom_start=12)

# Define H3 resolution (0 to 15)
resolution = 7

# Define bounding box coordinates
min_lat, min_lon = -2.984188,  51.269558
max_lat, max_lon = -2.416278, 51.56

# Create GeoJSON-like polygon
geo_json_polygon = {
    "type": "Polygon",
    "coordinates": [
        [
            [min_lon, min_lat],
            [min_lon, max_lat],
            [max_lon, max_lat],
            [max_lon, min_lat],
            [min_lon, min_lat]
        ]
    ]
}

# Generate H3 cells covering the map area
hexagons = h3.polyfill(geo_json_polygon, resolution)

# Check if hexagons list is not empty
if hexagons:
    for hexagon in hexagons:
        vertices = h3.h3_to_geo_boundary(hexagon)
        
        folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='yellow', fill_opacity=0.1).add_to(m)
      
       # Calculate the centroid of the polygon
        centroid_lat = sum(point[0] for point in vertices) / len(vertices)
        centroid_lon = sum(point[1] for point in vertices) / len(vertices)

        # Add label marker at the centroid of the polygon
        if hexagon.replace('0x', '') in df2.hex7.values:
            label=df2.total_charger[df2.hex7==hexagon.replace('0x', '') .replace('0x', '')].values[0] 
        else:
             label=''
        folium.Marker(location=[centroid_lat, centroid_lon], icon=folium.DivIcon(html=f'<div><font size=3><b>{label}</b></div>')).add_to(m)

    # Save the map to an HTML file

    m.save('h3_map.html')
    print("Hexagons drawn successfully!")
    
else:
    print("No hexagons generated.")
# Out:
# Hexagons drawn successfully!

# %%
# only our h3 values
import folium


# Initialize Folium map
m = folium.Map(location=[51.45498615600733, -2.594947745448589], zoom_start=12)

# Define H3 resolution (0 to 15)
resolution = 7

# Define bounding box coordinates
min_lat, min_lon = -2.984188,  51.269558
max_lat, max_lon = -2.416278, 51.56

# Create GeoJSON-like polygon
geo_json_polygon = {
    "type": "Polygon",
    "coordinates": [
        [
            [min_lon, min_lat],
            [min_lon, max_lat],
            [max_lon, max_lat],
            [max_lon, min_lat],
            [min_lon, min_lat]
        ]
    ]
}

# Generate H3 cells covering the map area
hexagons = h3.polyfill(geo_json_polygon, resolution)

# Check if hexagons list is not empty
if hexagons:
    for hexagon in hexagons:
        vertices = h3.h3_to_geo_boundary(hexagon)
        if hexagon.replace('0x', '') in df2.hex7.values:
            folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='yellow', fill_opacity=0.1).add_to(m)
        
        # Calculate the centroid of the polygon
            centroid_lat = sum(point[0] for point in vertices) / len(vertices)
            centroid_lon = sum(point[1] for point in vertices) / len(vertices)

        # Add label marker at the centroid of the polygon
           
            label=df2.total_charger[df2.hex7==hexagon.replace('0x', '') .replace('0x', '')].values[0] 
           
            folium.Marker(location=[centroid_lat, centroid_lon], icon=folium.DivIcon(html=f'<div><font size=3><b>{label}</b></div>')).add_to(m)

    # Save the map to an HTML file

    m.save('h3_map_Bristol.html')
    print("Hexagons drawn successfully!")
    
else:
    print("No hexagons generated.")
# Out:
# Hexagons drawn successfully!

# %%
# one h3 and neighbourhoods
import folium


# Initialize Folium map
m = folium.Map(location=[51.45498615600733, -2.594947745448589], zoom_start=12)

# Define H3 resolution (0 to 15)
resolution = 7

# Define the central hexagon
central_hexagon = '871958390ffffff'

# Generate H3 cells covering the map area in k-rings
hexagons = h3.k_ring(central_hexagon, 2)

# Sort the hexagons based on their distance from the central hexagon
sorted_hexagons = sorted(hexagons, key=lambda x: h3.h3_distance(central_hexagon, x))

# Print the sorted hexagons
for i, hexagon in enumerate(sorted_hexagons):
    print(f"Index {i}: {hexagon}")


# Check if hexagons list is not empty
if sorted_hexagons:
    label=0
    for hexagon in sorted_hexagons:
        vertices = h3.h3_to_geo_boundary(hexagon)
       # Add polygon to map
        folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='yellow', fill_opacity=0.1).add_to(m)
        
        # Calculate the centroid of the polygon
        centroid_lat = sum(point[0] for point in vertices) / len(vertices)
        centroid_lon = sum(point[1] for point in vertices) / len(vertices)

        # Add label marker at the centroid of the polygon
           
        folium.Marker(location=[centroid_lat, centroid_lon], icon=folium.DivIcon(html=f'<div><font size=3><b>{label}</b></div>')).add_to(m)
        label=label+1
    # Save the map to an HTML file

    m.save('h3_map_nd.html')
    print("Hexagons drawn successfully!")
    
else:
    print("No hexagons generated.")
# Out:
# Index 0: 871958390ffffff
# Index 1: 871958395ffffff
# Index 2: 871958396ffffff
# Index 3: 871958394ffffff
# Index 4: 871958393ffffff
# Index 5: 871958391ffffff
# Index 6: 871958392ffffff
# Index 7: 8719583b3ffffff
# Index 8: 87195839cffffff
# Index 9: 8719583b2ffffff
# Index 10: 8719580c9ffffff
# Index 11: 871958386ffffff
# Index 12: 871958765ffffff
# Index 13: 87195876cffffff
# Index 14: 8719580cbffffff
# Index 15: 87195876dffffff
# Index 16: 871958761ffffff
# Index 17: 871958382ffffff
# Index 18: 87195839effffff
# Hexagons drawn successfully!

# %%
df2.to_csv('./closest_chargers.csv', index=False)

# %%
#testing
result=getchargercount('871958390ffffff',1)
print(result)
# Out:
# 6

# %%
import matplotlib.pyplot as plt

# Define your data
mean_car = df2.mean_car.to_list()
total_charger = df2.total_charger.to_list()

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(mean_car, total_charger, color='blue', marker='o', alpha=0.7)

# Add labels and title
plt.title('Total Charger vs Total Car')
plt.xlabel('Total Car')
plt.ylabel('Total Charger')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Define your data
#       4 mean_car = df2.mean_car.to_list()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:61
#      58 from matplotlib import _docstring
#      59 from matplotlib.backend_bases import (
#      60     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 61 from matplotlib.figure import Figure, FigureBase, figaspect
#      62 from matplotlib.gridspec import GridSpec, SubplotSpec
#      63 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:43
#      40 import numpy as np
#      42 import matplotlib as mpl
# ---> 43 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      44 from matplotlib.artist import (
#      45     Artist, allow_rasterization, _finalize_rasterization)
#      46 from matplotlib.backend_bases import (
#      47     DrawEvent, FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\projections\__init__.py:55
#       1 """
#       2 Non-separable transforms that map from data space to screen space.
#       3
#    (...)
#      52 `matplotlib.projections.polar` may also be of interest.
#      53 """
# ---> 55 from .. import axes, _docstring
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\__init__.py:2
#       1 from . import _base
# ----> 2 from ._axes import *
#       4 # Backcompat.
#       5 from ._axes import Axes as Subplot
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:24
#      22 import matplotlib.patches as mpatches
#      23 import matplotlib.path as mpath
# ---> 24 import matplotlib.quiver as mquiver
#      25 import matplotlib.stackplot as mstack
#      26 import matplotlib.streamplot as mstream
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Define the data
mean_car = df2.mean_car.to_list()
total_charger = df2.total_charger.to_list()
# Convert lists to numpy arrays
X = np.array(mean_car).reshape(-1, 1)  # Feature matrix
y = np.array(total_charger)             # Target vector

# Define polynomial features
poly_features = PolynomialFeatures(degree=2)  # You can adjust the degree as needed
X_poly = poly_features.fit_transform(X)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Print the coefficients
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [ 0.00000000e+00  1.51238966e-02 -4.82186232e-06]
# Intercept: 1.1174251207422854
